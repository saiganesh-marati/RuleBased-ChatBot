# %% [markdown]
# # Importing Modules

# %%
import spacy
sp = spacy.load('en_core_web_sm')

# %% [markdown]
# # Conversion of  Requests to Words

# %%
sen1=sp(u"hi,hey ,hello") 
sen2=sp(u"How are you doing . how are you ?")
sen3=sp(u"who are you. what are you")
sen4=sp(u"who made you?")
sen5=sp(u"university website") 
sen6=sp(u"About SRU,about sru")
sen7=sp(u"Academics,academics")
sen8=sp(u"placement,Placement")
sen9=sp(u"Srapp,attendance,Attendance")
sen10=sp(u"srix,SRIX ,Srix")
sen11=sp(u"careers,Careers")
sen12=sp(u"campuslife")
sen13=sp(u"examfee ,results website")
sen14=sp(u"SRU ,sru ,What is fullform of sru? ,What is fullform of sru")
sen15=sp(u"quit")

# %% [markdown]
# # Conversion of Responses to Words

# %%
senn1=sp(u"Hello.hey there")
senn2=sp(u"I 'm doing great.")
senn3=sp(u"I 'm SRU Bot")
senn4=sp(u"Saiganesh,Harshith,karthik,manindhar")
senn5=sp(u"try to visit ->https://sru.edu.in/")
senn6=sp(u"Sri Rajeshwara Educational Society, the parent body of SR University is a 45-year-old conglomerate of educational institutions with more than 90,000 students and 10,000 teaching and non-teaching staff members. SR Educational Academy governs 95 Educational Institutions across Telangana and Andhra Pradesh.The goal of SR University is to create an innovative learning educational ecosystem whose graduates significantly contribute to the growth of Telangana and India. We plan to transform the educational system through three key differentiators for more information try to visit ->https://sru.edu.in/about ")
senn7=sp(u"try to visit ->https://sru.edu.in/schools/Academics")
senn8=sp(u"The Centre for Student Services and Placements (CSSP) coordinates the placement activities at SR University. The Centre ensures smooth functioning of placement activities on campus, and facilitates training activities of the students. It makes sure that all eligible and interested students are given the best support in getting placed. Leading companies across various disciplines visit SRU for campus placements. At SR University, it is our incessant endeavor to make all our students industry ready.The CSSP has designed a campus recruitment training program and is delivering from the first year onwards. The focus areas @ CSSP include communication skills, soft skills, programming, aptitude and logical reasoning training.Boot camps in summer, professional certifications, hackathons and coding competitions are part of the center’s efforts in ensuring valuable student placement opportunities.for more information,try to visit ->https://sru.edu.in/placement ")
senn9=sp(u"try to visit ->http://103.65.202.101/sraap/ ")
senn10=sp(u"SRiX is the Technology Business Incubator - TBI of SR University, Telangana.We nurture startup ideas and technology innovations from their idea stage, provide the resources required to build products and find customer acceptance. We also support the startups to gear for growth through access to global partners and investors.SRiX brings entrepreneurs, mentors, researchers, and academicians together to create an inspiring ecosystem to transform ideas into actions. The deep interaction between the theory and practice of entrepreneurship brings the best out of both, creating unique synergies.SRiX intends to be an active catalyst for the growth of Telanganas startup eco-system. We are an open incubator that welcomes entrepreneurs from all over the country.Be a part of our network to participate in stimulating conversations, innovative thinking, and forward-looking startups. Together, let us ignite the spark of new ideas and ventures..for more information,try to visit ->https://www.srix.in/ ")
senn11=sp(u"try to visit ->https://sru.edu.in/careers")
senn12=sp(u"The Sports Program at SRU is designed to serve student interest in different sports and recreational activities. These interests are competitive, recreational or instructional in nature.With a firm belief that a sound mind resides in a sound body, students have access to the following facilities:for more information,try to visit ->https://sru.edu.in/Campuslife ", )
senn13=sp(u"try to visit ->https://examfee.in/")
senn14=sp(u"SR UNIVERSITY")
senn15=sp(u" Bye,take care.See you soon :) .it was nice to talking to you,See you soon :)")

# %% [markdown]
# # Parts of Speech-Tagging for Requests

# %%
sen1=sp(u"hi,hey ,hello")
print(sen1.text)
print(sen1[0].pos_)
for word in sen1:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen1.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen1.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen1=sp(u"hi ,hey ,hello")

displacy.render(sen1, style='dep', jupyter=True, options={'distance': 85})
# Out:
# hi,hey ,hello
# INTJ
# hi           INTJ       UH       interjection
# ,            PUNCT      ,        punctuation mark, comma
# hey          INTJ       UH       interjection
# ,            PUNCT      ,        punctuation mark, comma
# hello        INTJ       UH       interjection
# parts of speech :wordcount
# 91. INTJ    : 3
# 97. PUNCT   : 2
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="64196b121e5640c494166c86fdbebc43-0" class="displacy" width="305" height="179.5" direction="ltr" style="max-width: none; height: 179.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">hi ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# ...

# %%
sen2=sp(u"How are you doing . how are you ?")
print(sen2.text)
print(sen2[4].pos_)
for word in sen2:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen2.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen2.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen2=sp(u"How are you doing . how are you ?")


displacy.render(sen2, style='dep', jupyter=True, options={'distance': 85})
# Out:
# How are you doing . how are you ?
# PUNCT
# How          SCONJ      WRB      wh-adverb
# are          AUX        VBP      verb, non-3rd person singular present
# you          PRON       PRP      pronoun, personal
# doing        VERB       VBG      verb, gerund or present participle
# .            PUNCT      .        punctuation mark, sentence closer
# how          SCONJ      WRB      wh-adverb
# are          AUX        VBP      verb, non-3rd person singular present
# you          PRON       PRP      pronoun, personal
# ?            PUNCT      .        punctuation mark, sentence closer
# parts of speech :wordcount
# 87. AUX     : 2
# 95. PRON    : 2
# 97. PUNCT   : 2
# 98. SCONJ   : 2
# 100. VERB    : 1
# ...

# %%
sen3=sp(u"who are you. what are you")
print(sen3.text)
print(sen3[0].pos_)
for word in sen3:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen3.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen3.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen3=sp(u"who are you. what are you")


displacy.render(sen3, style='dep', jupyter=True, options={'distance': 85})
# Out:
# who are you. what are you
# PRON
# who          PRON       WP       wh-pronoun, personal
# are          AUX        VBP      verb, non-3rd person singular present
# you          PRON       PRP      pronoun, personal
# .            PUNCT      .        punctuation mark, sentence closer
# what         PRON       WP       wh-pronoun, personal
# are          AUX        VBP      verb, non-3rd person singular present
# you          PRON       PRP      pronoun, personal
# parts of speech :wordcount
# 87. AUX     : 2
# 95. PRON    : 4
# 97. PUNCT   : 1
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a4a2ad1f38c34ec59e38e9054bde434b-0" class="displacy" width="560" height="179.5" direction="ltr" style="max-width: none; height: 179.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
# ...

# %%
sen4=sp(u"who made you?")
print(sen4.text)
print(sen4[0].pos_)
for word in sen4:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen4.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen4.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen4=sp(u"who made you?")
displacy.render(sen4, style='dep', jupyter=True, options={'distance': 85})
# Out:
# who made you?
# PRON
# who          PRON       WP       wh-pronoun, personal
# made         VERB       VBD      verb, past tense
# you          PRON       PRP      pronoun, personal
# ?            PUNCT      .        punctuation mark, sentence closer
# parts of speech :wordcount
# 95. PRON    : 2
# 97. PUNCT   : 1
# 100. VERB    : 1
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c07d7173a9394c4b9beb73a7e0106d5f-0" class="displacy" width="305" height="179.5" direction="ltr" style="max-width: none; height: 179.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# ...

# %%
sen5=sp(u"university website")
print(sen5.text)
print(sen5[0].pos_)
for word in sen5:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen5.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen5.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen5=sp(u"university website")
displacy.render(sen5, style='dep', jupyter=True, options={'distance': 85})
# Out:
# university website
# NOUN
# university   NOUN       NN       noun, singular or mass
# website      NOUN       NN       noun, singular or mass
# parts of speech :wordcount
# 92. NOUN    : 2
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="15fe7ce81af74f09ab5037233e3a0709-0" class="displacy" width="220" height="179.5" direction="ltr" style="max-width: none; height: 179.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">university</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
#     <tspan class="displacy-word" fill="currentColor" x="135">website</tspan>
# ...

# %%
sen6=sp(u"About SRU,about sru")
print(sen6.text)
print(sen6[0].pos_)
for word in sen6:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen6.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen6.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen6=sp(u"About SRU,about sru")
displacy.render(sen6, style='dep', jupyter=True, options={'distance': 85})
# Out:
# About SRU,about sru
# ADP
# About        ADP        IN       conjunction, subordinating or preposition
# SRU          PROPN      NNP      noun, proper singular
# ,            PUNCT      ,        punctuation mark, comma
# about        ADP        IN       conjunction, subordinating or preposition
# sru          NOUN       NN       noun, singular or mass
# parts of speech :wordcount
# 85. ADP     : 2
# 92. NOUN    : 1
# 96. PROPN   : 1
# 97. PUNCT   : 1
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="767617720ce041daa9fc4f0565c1457a-0" class="displacy" width="390" height="222.0" direction="ltr" style="max-width: none; height: 222.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">About</tspan>
# ...

# %%
sen7=sp(u"Academics,academics")
print(sen7.text)
print(sen7[0].pos_)
for word in sen7:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen7.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen7.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen7=sp(u"Academics,academics")
displacy.render(sen7, style='dep', jupyter=True, options={'distance': 85})
# Out:
# Academics,academics
# NOUN
# Academics    NOUN       NNS      noun, plural
# ,            PUNCT      ,        punctuation mark, comma
# academics    NOUN       NNS      noun, plural
# parts of speech :wordcount
# 92. NOUN    : 2
# 97. PUNCT   : 1
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d0dd71df56734d94bdbc802759afdfe6-0" class="displacy" width="220" height="179.5" direction="ltr" style="max-width: none; height: 179.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Academics,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
# ...

# %%
sen8=sp(u"placement.Placement")
print(sen8.text)
print(sen8[0].pos_)
for word in sen8:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen8.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen8.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen8=sp(u"placement,Placement")
displacy.render(sen8, style='dep', jupyter=True, options={'distance': 85})
# Out:
# placement.Placement
# NOUN
# placement    NOUN       NN       noun, singular or mass
# .            PUNCT      .        punctuation mark, sentence closer
# Placement    NOUN       NN       noun, singular or mass
# parts of speech :wordcount
# 92. NOUN    : 2
# 97. PUNCT   : 1
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="875c57f9f68c42ffa740b55f5bdb5a52-0" class="displacy" width="220" height="179.5" direction="ltr" style="max-width: none; height: 179.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">placement,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
# ...

# %%
sen9=sp(u"Srapp,attendance,Attendance")
print(sen9.text)
print(sen9[0].pos_)
for word in sen9:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen9.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen9.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen9=sp(u"Srapp,attendance,Attendance")
displacy.render(sen9, style='dep', jupyter=True, options={'distance': 85})
# Out:
# Srapp,attendance,Attendance
# PROPN
# Srapp        PROPN      NNP      noun, proper singular
# ,            PUNCT      ,        punctuation mark, comma
# attendance   NOUN       NN       noun, singular or mass
# ,            PUNCT      ,        punctuation mark, comma
# Attendance   NOUN       NN       noun, singular or mass
# parts of speech :wordcount
# 92. NOUN    : 2
# 96. PROPN   : 1
# 97. PUNCT   : 2
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e61781917b2b4122830166af575288ec-0" class="displacy" width="305" height="222.0" direction="ltr" style="max-width: none; height: 222.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Srapp,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# ...

# %%
sen10=sp(u"srix,SRIX,Srix")
print(sen10.text)
print(sen10[0].pos_)
for word in sen10:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen10.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen10.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen10=sp(u"srix,SRIX ,Srix")
displacy.render(sen10, style='dep', jupyter=True, options={'distance': 85})
# Out:
# srix,SRIX,Srix
# NOUN
# srix         NOUN       NN       noun, singular or mass
# ,            PUNCT      ,        punctuation mark, comma
# SRIX         PROPN      NNP      noun, proper singular
# ,            PUNCT      ,        punctuation mark, comma
# Srix         PROPN      NNP      noun, proper singular
# parts of speech :wordcount
# 92. NOUN    : 1
# 96. PROPN   : 2
# 97. PUNCT   : 2
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d65a8b38b42544cd9be3b19e19434168-0" class="displacy" width="305" height="222.0" direction="ltr" style="max-width: none; height: 222.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">srix,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# ...

# %%
sen11=sp(u"careers,Careers")
print(sen11.text)
print(sen11[0].pos_)
for word in sen11:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen11.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen11.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen11=sp(u"careers,Careers")
displacy.render(sen11, style='dep', jupyter=True, options={'distance': 85})
# Out:
# careers,Careers
# NOUN
# careers      NOUN       NNS      noun, plural
# ,            PUNCT      ,        punctuation mark, comma
# Careers      NOUN       NNS      noun, plural
# parts of speech :wordcount
# 92. NOUN    : 2
# 97. PUNCT   : 1
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5115cb23e9ca45d18886f2f098ff93ee-0" class="displacy" width="220" height="179.5" direction="ltr" style="max-width: none; height: 179.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">careers,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
# ...

# %%
sen12=sp(u"campuslife")
print(sen12.text)
print(sen12[0].pos_)
for word in sen12:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen12.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen12.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen12=sp(u"campuslife")
displacy.render(sen12, style='dep', jupyter=True, options={'distance': 85})
# Out:
# campuslife
# NOUN
# campuslife   NOUN       NN       noun, singular or mass
# parts of speech :wordcount
# 92. NOUN    : 1
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d31e972aa5af492c82ba6f7f0a1dc0ad-0" class="displacy" width="135" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">campuslife</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
# </svg></span>

# %%
sen13=sp(u"examfee ,results website")
print(sen13.text)
print(sen13[0].pos_)
for word in sen13:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen13.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen13.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen13=sp(u"examfee ,results website")
displacy.render(sen13, style='dep', jupyter=True, options={'distance': 85})
# Out:
# examfee ,results website
# NOUN
# examfee      NOUN       NN       noun, singular or mass
# ,            PUNCT      ,        punctuation mark, comma
# results      NOUN       NNS      noun, plural
# website      VERB       VBP      verb, non-3rd person singular present
# parts of speech :wordcount
# 92. NOUN    : 2
# 97. PUNCT   : 1
# 100. VERB    : 1
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="59c2ce988c65431fb4f8297fe7ff9ec5-0" class="displacy" width="305" height="222.0" direction="ltr" style="max-width: none; height: 222.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">examfee ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# ...

# %%
sen14=sp(u"SRU ,sru ,What is fullform of sru? ,What is fullform of sru")
print(sen14.text)
print(sen14[0].pos_)
for word in sen14:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen14.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen14.vocab[k].text:{8}}: {v}')
from spacy import displacy
sen14=sp(u"SRU ,sru ,What is fullform of sru? ,What is fullform of sru")
displacy.render(sen14, style='dep', jupyter=True, options={'distance': 85})
# Out:
# SRU ,sru ,What is fullform of sru? ,What is fullform of sru
# PROPN
# SRU          PROPN      NNP      noun, proper singular
# ,            PUNCT      ,        punctuation mark, comma
# sru          NOUN       NN       noun, singular or mass
# ,            PUNCT      ,        punctuation mark, comma
# What         PRON       WP       wh-pronoun, personal
# is           AUX        VBZ      verb, 3rd person singular present
# fullform     NOUN       NN       noun, singular or mass
# of           ADP        IN       conjunction, subordinating or preposition
# sru          NOUN       NN       noun, singular or mass
# ?            PUNCT      .        punctuation mark, sentence closer
# ,            PUNCT      ,        punctuation mark, comma
# What         PRON       WP       wh-pronoun, personal
# is           AUX        VBZ      verb, 3rd person singular present
# fullform     NOUN       NN       noun, singular or mass
# ...

# %%
sen15=sp(u"quit")
print(sen15.text)
print(sen15[0].pos_)
for word in sen15:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = sen15.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {sen15.vocab[k].text:{8}}: {v}')
from spacy import displacy

displacy.render(sen15, style='dep', jupyter=True, options={'distance': 85})
# Out:
# quit
# VERB
# quit         VERB       VB       verb, base form
# parts of speech :wordcount
# 100. VERB    : 1
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8e143767c79b4fa187e676f085e191df-0" class="displacy" width="135" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">quit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
# </svg></span>

# %% [markdown]
# # Parts of Speech-Tagging for Responses

# %%
senn1=sp(u"Hello ,hey there")
print(senn1.text)
print(senn1[0].pos_)
for word in senn1:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn1.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn1.vocab[k].text:{8}}: {v}')
from spacy import displacy
senn1=sp(u"Hello,hey there")

displacy.render(senn1, style='dep', jupyter=True, options={'distance': 85})
# Out:
# Hello ,hey there
# INTJ
# Hello        INTJ       UH       interjection
# ,            PUNCT      ,        punctuation mark, comma
# hey          INTJ       UH       interjection
# there        ADV        RB       adverb
# parts of speech :wordcount
# 86. ADV     : 1
# 91. INTJ    : 2
# 97. PUNCT   : 1
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e968fde3260848c69e8a33f3419f1f4d-0" class="displacy" width="305" height="179.5" direction="ltr" style="max-width: none; height: 179.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
# ...

# %%
senn2=sp(u"I 'm doing great.")

print(senn2.text)
print(senn2[2].pos_)
for word in senn2:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn1.count_by(spacy.attrs.POS)
num_pos
print("parts of speech :wordcount")
#word count
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn2.vocab[k].text:{8}}: {v}')
from spacy import displacy
senn2=sp(u"I 'm doing great.")

displacy.render(senn2, style='dep', jupyter=True, options={'distance': 85})
# Out:
# I 'm doing great.
# AUX
# I            PRON       PRP      pronoun, personal
# '            AUX        VBP      verb, non-3rd person singular present
# m            AUX        VBP      verb, non-3rd person singular present
# doing        VERB       VBG      verb, gerund or present participle
# great        ADJ        JJ       adjective (English), other noun-modifier (Chinese)
# .            PUNCT      .        punctuation mark, sentence closer
# parts of speech :wordcount
# 86. ADV     : 1
# 91. INTJ    : 2
# 97. PUNCT   : 1
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="00aa52114de243709dfa851f9fbacee8-0" class="displacy" width="390" height="222.0" direction="ltr" style="max-width: none; height: 222.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
# ...

# %%
senn3=sp(u"I 'm SRU Bot")


print(senn3.text)
print(senn3[2].pos_)
for word in senn3:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn3.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn3.vocab[k].text:{8}}: {v}')
from spacy import displacy
senn3=sp(u"I 'm SRU Bot")

displacy.render(senn3, style='dep', jupyter=True, options={'distance': 85})
# Out:
# I 'm SRU Bot
# VERB
# I            PRON       PRP      pronoun, personal
# '            VERB       VBP      verb, non-3rd person singular present
# m            VERB       VBP      verb, non-3rd person singular present
# SRU          PROPN      NNP      noun, proper singular
# Bot          PROPN      NNP      noun, proper singular
# parts of speech :wordcount
# 95. PRON    : 1
# 96. PROPN   : 2
# 100. VERB    : 2
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2b41c37baf554db3b2bad7157a0136cd-0" class="displacy" width="390" height="264.5" direction="ltr" style="max-width: none; height: 264.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">I '</tspan>
# ...

# %%
senn4=sp(u"Saiganesh,Harshith,karthik,manindhar")

print(senn4.text)
print(senn4[2].pos_)
for word in senn4:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn4.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn4.vocab[k].text:{8}}: {v}')
from spacy import displacy
senn4=sp(u"Saiganesh,Harshith,karthik,manindhar")

displacy.render(senn4, style='dep', jupyter=True, options={'distance': 85})
# Out:
# Saiganesh,Harshith,karthik,manindhar
# PROPN
# Saiganesh    NOUN       NN       noun, singular or mass
# ,            PUNCT      ,        punctuation mark, comma
# Harshith     PROPN      NNP      noun, proper singular
# ,            PUNCT      ,        punctuation mark, comma
# karthik      PROPN      NNP      noun, proper singular
# ,            PUNCT      ,        punctuation mark, comma
# manindhar    PROPN      NNP      noun, proper singular
# parts of speech :wordcount
# 92. NOUN    : 1
# 96. PROPN   : 3
# 97. PUNCT   : 3
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cc8f7e469f894dc5b50b46c4edd8ecc4-0" class="displacy" width="390" height="222.0" direction="ltr" style="max-width: none; height: 222.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
# ...

# %%
senn5=sp(u"try to visit ->https://sru.edu.in/")
print(senn5.text)
print(senn5[2].pos_)
for word in senn5:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn5.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn5.vocab[k].text:{8}}: {v}')
from spacy import displacy
senn5=sp(u"try to visit ->https://sru.edu.in/")

displacy.render(senn5, style='dep', jupyter=True, options={'distance': 85})
# Out:
# try to visit ->https://sru.edu.in/
# VERB
# try          VERB       VB       verb, base form
# to           PART       TO       infinitival "to"
# visit        VERB       VB       verb, base form
# ->https://sru.edu.in/ NOUN       NNS      noun, plural
# parts of speech :wordcount
# 92. NOUN    : 1
# 94. PART    : 1
# 100. VERB    : 2
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="64be3cd94db440c0973438fccec65b25-0" class="displacy" width="390" height="222.0" direction="ltr" style="max-width: none; height: 222.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">try</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# ...

# %%
senn6=sp(u"Sri Rajeshwara Educational Society, the parent body of SR University is a 45-year-old conglomerate of educational institutions with more than 90,000 students and 10,000 teaching and non-teaching staff members. SR Educational Academy governs 95 Educational Institutions across Telangana and Andhra Pradesh.The goal of SR University is to create an innovative learning educational ecosystem whose graduates significantly contribute to the growth of Telangana and India. We plan to transform the educational system through three key differentiators for more information try to visit ->https://sru.edu.in/about ")
print(senn6.text)
print(senn6[2].pos_)
for word in senn6:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn6.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn6.vocab[k].text:{8}}: {v}')
from spacy import displacy
senn6=sp(u"Sri Rajeshwara Educational Society, the parent body of SR University is a 45-year-old conglomerate of educational institutions with more than 90,000 students and 10,000 teaching and non-teaching staff members. SR Educational Academy governs 95 Educational Institutions across Telangana and Andhra Pradesh.The goal of SR University is to create an innovative learning educational ecosystem whose graduates significantly contribute to the growth of Telangana and India. We plan to transform the educational system through three key differentiators for more information try to visit ->https://sru.edu.in/about ")
displacy.render(senn6, style='dep', jupyter=True, options={'distance': 85})
# Out:
# Sri Rajeshwara Educational Society, the parent body of SR University is a 45-year-old conglomerate of educational institutions with more than 90,000 students and 10,000 teaching and non-teaching staff members. SR Educational Academy governs 95 Educational Institutions across Telangana and Andhra Pradesh.The goal of SR University is to create an innovative learning educational ecosystem whose graduates significantly contribute to the growth of Telangana and India. We plan to transform the educational system through three key differentiators for more information try to visit ->https://sru.edu.in/about
# PROPN
# Sri          PROPN      NNP      noun, proper singular
# Rajeshwara   PROPN      NNP      noun, proper singular
# Educational  PROPN      NNP      noun, proper singular
# Society      PROPN      NNP      noun, proper singular
# ,            PUNCT      ,        punctuation mark, comma
# the          DET        DT       determiner
# ...

# %%
senn7=sp(u"try to visit ->https://sru.edu.in/schools/Academics")
print(senn7.text)
print(senn7[2].pos_)
for word in senn7:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn7.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn7.vocab[k].text:{8}}: {v}')
from spacy import displacy
senn7=sp(u"try to visit ->https://sru.edu.in/schools/Academics")

displacy.render(senn7, style='dep', jupyter=True, options={'distance': 85})
# Out:
# try to visit ->https://sru.edu.in/schools/Academics
# VERB
# try          VERB       VB       verb, base form
# to           PART       TO       infinitival "to"
# visit        VERB       VB       verb, base form
# ->https://sru.edu.in NOUN       NN       noun, singular or mass
# /            SYM        SYM      symbol
# schools      NOUN       NNS      noun, plural
# /            PUNCT      .        punctuation mark, sentence closer
# Academics    NOUN       NNS      noun, plural
# parts of speech :wordcount
# 92. NOUN    : 3
# 94. PART    : 1
# 97. PUNCT   : 1
# 99. SYM     : 1
# 100. VERB    : 2
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="35b37ec248644766ad352530dab001dc-0" class="displacy" width="560" height="264.5" direction="ltr" style="max-width: none; height: 264.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# ...

# %%
senn8=sp(u"The Centre for Student Services and Placements (CSSP) coordinates the placement activities at SR University. The Centre ensures smooth functioning of placement activities on campus, and facilitates training activities of the students. It makes sure that all eligible and interested students are given the best support in getting placed. Leading companies across various disciplines visit SRU for campus placements. At SR University, it is our incessant endeavor to make all our students industry ready.The CSSP has designed a campus recruitment training program and is delivering from the first year onwards. The focus areas @ CSSP include communication skills, soft skills, programming, aptitude and logical reasoning training.Boot camps in summer, professional certifications, hackathons and coding competitions are part of the center’s efforts in ensuring valuable student placement opportunities.for more information,try to visit ->https://sru.edu.in/placement ")
print(senn8.text)
print(senn8[2].pos_)
for word in senn8:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn8.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn8.vocab[k].text:{8}}: {v}')
from spacy import displacy
senn8=sp(u"The Centre for Student Services and Placements (CSSP) coordinates the placement activities at SR University. The Centre ensures smooth functioning of placement activities on campus, and facilitates training activities of the students. It makes sure that all eligible and interested students are given the best support in getting placed. Leading companies across various disciplines visit SRU for campus placements. At SR University, it is our incessant endeavor to make all our students industry ready.The CSSP has designed a campus recruitment training program and is delivering from the first year onwards. The focus areas @ CSSP include communication skills, soft skills, programming, aptitude and logical reasoning training.Boot camps in summer, professional certifications, hackathons and coding competitions are part of the center’s efforts in ensuring valuable student placement opportunities.for more information,try to visit ->https://sru.edu.in/placement ")


displacy.render(senn8, style='dep', jupyter=True, options={'distance': 85})
# Out:
# The Centre for Student Services and Placements (CSSP) coordinates the placement activities at SR University. The Centre ensures smooth functioning of placement activities on campus, and facilitates training activities of the students. It makes sure that all eligible and interested students are given the best support in getting placed. Leading companies across various disciplines visit SRU for campus placements. At SR University, it is our incessant endeavor to make all our students industry ready.The CSSP has designed a campus recruitment training program and is delivering from the first year onwards. The focus areas @ CSSP include communication skills, soft skills, programming, aptitude and logical reasoning training.Boot camps in summer, professional certifications, hackathons and coding competitions are part of the center’s efforts in ensuring valuable student placement opportunities.for more information,try to visit ->https://sru.edu.in/placement
# ADP
# ...

# %%
senn9=sp(u"try to visit ->http://103.65.202.101/sraap/ ")
print(senn9.text)
print(senn9[2].pos_)
for word in senn9:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn9.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn9.vocab[k].text:{8}}: {v}')
from spacy import displacy
senn9=sp(u"try to visit ->http://103.65.202.101/sraap/ ")

displacy.render(senn9, style='dep', jupyter=True, options={'distance': 85})
# Out:
# try to visit ->http://103.65.202.101/sraap/
# VERB
# try          VERB       VB       verb, base form
# to           PART       TO       infinitival "to"
# visit        VERB       VB       verb, base form
# ->http://103.65.202.101 PUNCT      .        punctuation mark, sentence closer
# /            SYM        SYM      symbol
# sraap/       NUM        CD       cardinal number
# parts of speech :wordcount
# 93. NUM     : 1
# 94. PART    : 1
# 97. PUNCT   : 1
# 99. SYM     : 1
# 100. VERB    : 2
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="930ab7b513e54d5e82cc14609ced81b4-0" class="displacy" width="475" height="307.0" direction="ltr" style="max-width: none; height: 307.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">try</tspan>
# ...

# %%
senn10=sp(u"SRiX is the Technology Business Incubator - TBI of SR University, Telangana.We nurture startup ideas and technology innovations from their idea stage, provide the resources required to build products and find customer acceptance. We also support the startups to gear for growth through access to global partners and investors.SRiX brings entrepreneurs, mentors, researchers, and academicians together to create an inspiring ecosystem to transform ideas into actions. The deep interaction between the theory and practice of entrepreneurship brings the best out of both, creating unique synergies.SRiX intends to be an active catalyst for the growth of Telanganas startup eco-system. We are an open incubator that welcomes entrepreneurs from all over the country.Be a part of our network to participate in stimulating conversations, innovative thinking, and forward-looking startups. Together, let us ignite the spark of new ideas and ventures..for more information,try to visit ->https://www.srix.in/ ")
print(senn10.text)
print(senn10[22].pos_)
for word in senn10:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn10.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn10.vocab[k].text:{8}}: {v}')
from spacy import displacy

displacy.render(senn10, style='dep', jupyter=True, options={'distance': 85})
# Out:
# SRiX is the Technology Business Incubator - TBI of SR University, Telangana.We nurture startup ideas and technology innovations from their idea stage, provide the resources required to build products and find customer acceptance. We also support the startups to gear for growth through access to global partners and investors.SRiX brings entrepreneurs, mentors, researchers, and academicians together to create an inspiring ecosystem to transform ideas into actions. The deep interaction between the theory and practice of entrepreneurship brings the best out of both, creating unique synergies.SRiX intends to be an active catalyst for the growth of Telanganas startup eco-system. We are an open incubator that welcomes entrepreneurs from all over the country.Be a part of our network to participate in stimulating conversations, innovative thinking, and forward-looking startups. Together, let us ignite the spark of new ideas and ventures..for more information,try to visit ->https://www.srix.in
# ...

# %%
senn11=sp(u"try to visit ->https://sru.edu.in/careers")
print(senn11.text)
print(senn11[2].pos_)
for word in senn11:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn11.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn11.vocab[k].text:{8}}: {v}')
from spacy import displacy


displacy.render(senn11, style='dep', jupyter=True, options={'distance': 85})
# Out:
# try to visit ->https://sru.edu.in/careers
# VERB
# try          VERB       VB       verb, base form
# to           PART       TO       infinitival "to"
# visit        VERB       VB       verb, base form
# ->https://sru.edu.in NOUN       NN       noun, singular or mass
# /            SYM        SYM      symbol
# careers      NOUN       NNS      noun, plural
# parts of speech :wordcount
# 92. NOUN    : 2
# 94. PART    : 1
# 99. SYM     : 1
# 100. VERB    : 2
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c2939ee3d7bf446fb155adf3200b62a9-0" class="displacy" width="475" height="222.0" direction="ltr" style="max-width: none; height: 222.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">try</tspan>
# ...

# %%
senn12=sp(u"The Sports Program at SRU is designed to serve student interest in different sports and recreational activities. These interests are competitive, recreational or instructional in nature.With a firm belief that a sound mind resides in a sound body, students have access to the following facilities:for more information,try to visit ->https://sru.edu.in/Campuslife ", )
print(senn12.text)
print(senn12[20].pos_)
for word in senn12:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn12.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn12.vocab[k].text:{8}}: {v}')
from spacy import displacy

displacy.render(senn12, style='dep', jupyter=True, options={'distance': 85})
# Out:
# The Sports Program at SRU is designed to serve student interest in different sports and recreational activities. These interests are competitive, recreational or instructional in nature.With a firm belief that a sound mind resides in a sound body, students have access to the following facilities:for more information,try to visit ->https://sru.edu.in/Campuslife
# AUX
# The          DET        DT       determiner
# Sports       PROPN      NNPS     noun, proper plural
# Program      PROPN      NNP      noun, proper singular
# at           ADP        IN       conjunction, subordinating or preposition
# SRU          PROPN      NNP      noun, proper singular
# is           AUX        VBZ      verb, 3rd person singular present
# designed     VERB       VBN      verb, past participle
# to           PART       TO       infinitival "to"
# serve        VERB       VB       verb, base form
# student      NOUN       NN       noun, singular or mass
# ...

# %%
senn13=sp(u"try to visit ->https://examfee.in/")
print(senn13.text)
print(senn13[2].pos_)
for word in senn13:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn13.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn13.vocab[k].text:{8}}: {v}')
from spacy import displacy

displacy.render(senn13, style='dep', jupyter=True, options={'distance': 85})
# Out:
# try to visit ->https://examfee.in/
# VERB
# try          VERB       VB       verb, base form
# to           PART       TO       infinitival "to"
# visit        VERB       VB       verb, base form
# ->https://examfee.in/ NOUN       NNS      noun, plural
# parts of speech :wordcount
# 92. NOUN    : 1
# 94. PART    : 1
# 100. VERB    : 2
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="068f37113cb54559b9d8fd834a4c6980-0" class="displacy" width="390" height="222.0" direction="ltr" style="max-width: none; height: 222.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="132.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">try</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# ...

# %%
senn14=sp(u"SR UNIVERSITY")
print(senn14.text)
print(senn14[0].pos_)
for word in senn14:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn14.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn14.vocab[k].text:{8}}: {v}')
from spacy import displacy


displacy.render(senn14, style='dep', jupyter=True, options={'distance': 85})
# Out:
# SR UNIVERSITY
# PROPN
# SR           PROPN      NNP      noun, proper singular
# UNIVERSITY   PROPN      NNP      noun, proper singular
# parts of speech :wordcount
# 96. PROPN   : 2
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="29c364e8904a40b5897a9bc4d2291a01-0" class="displacy" width="220" height="179.5" direction="ltr" style="max-width: none; height: 179.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">SR</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="89.5">
#     <tspan class="displacy-word" fill="currentColor" x="135">UNIVERSITY</tspan>
# ...

# %%
senn15=sp(u"Bye,take care.See you soon :) .it was nice to talking to you,See you soon :)")
print(senn15.text)
print(senn15[2].pos_)
for word in senn15:
    print(f'{word.text:{12}} {word.pos_:{10}} {word.tag_:{8}} {spacy.explain(word.tag_)}')
num_pos = senn15.count_by(spacy.attrs.POS)
num_pos
#word count
print("parts of speech :wordcount")
for k,v in sorted(num_pos.items()):
    print(f'{k}. {senn15.vocab[k].text:{8}}: {v}')
from spacy import displacy
displacy.render(senn15, style='dep', jupyter=True, options={'distance': 85})
# Out:
# Bye,take care.See you soon :) .it was nice to talking to you,See you soon :)
# VERB
# Bye          INTJ       UH       interjection
# ,            PUNCT      ,        punctuation mark, comma
# take         VERB       VB       verb, base form
# care         NOUN       NN       noun, singular or mass
# .            PUNCT      .        punctuation mark, sentence closer
# See          VERB       VB       verb, base form
# you          PRON       PRP      pronoun, personal
# soon         ADV        RB       adverb
# :)           PROPN      NNP      noun, proper singular
# .it          PUNCT      .        punctuation mark, sentence closer
# was          AUX        VBD      verb, past tense
# nice         ADJ        JJ       adjective (English), other noun-modifier (Chinese)
# to           ADP        IN       conjunction, subordinating or preposition
# talking      VERB       VBG      verb, gerund or present participle
# ...
