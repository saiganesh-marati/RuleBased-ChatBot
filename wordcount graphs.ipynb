# %%
import nltk
from nltk import FreqDist
text ="How are you doing . how are you ?"
word = nltk.word_tokenize(text.lower())
freq = FreqDist(word)
print(freq.most_common(5))

import matplotlib.pyplot as plt

import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline

sns.set(rc={'figure.figsize': (11.7,8.27)})
sns.set_style('darkgrid')

# Create freq dist and plot
nlp_words = nltk.FreqDist (freq)

nlp_words.plot(20)
# Out:
# [('how', 2), ('are', 2), ('you', 2), ('doing', 1), ('.', 1)]
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
import nltk
from nltk import FreqDist
text ="who are you. what are you?"
word = nltk.word_tokenize(text.lower())
freq = FreqDist(word)
print(freq.most_common(5))

import matplotlib.pyplot as plt

import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline

sns.set(rc={'figure.figsize': (11.7,8.27)})
sns.set_style('darkgrid')

# Create freq dist and plot
nlp_words = nltk.FreqDist (freq)

nlp_words.plot(20)
# Out:
# [('are', 2), ('you', 2), ('who', 1), ('.', 1), ('what', 1)]
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # about sru

# %%
import nltk
from nltk import FreqDist
text ="Sri Rajeshwara Educational Society, the parent body of SR University is a 45-year-old conglomerate of educational institutions with more than 90,000 students and 10,000 teaching and non-teaching staff members. SR Educational Academy governs 95 Educational Institutions across Telangana and Andhra Pradesh.The goal of SR University is to create an innovative learning educational ecosystem whose graduates significantly contribute to the growth of Telangana and India. We plan to transform the educational system through three key differentiators"
word = nltk.word_tokenize(text.lower())
freq = FreqDist(word)
print(freq.most_common(100))

import matplotlib.pyplot as plt

import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline

sns.set(rc={'figure.figsize': (11.7,8.27)})
sns.set_style('darkgrid')

# Create freq dist and plot
nlp_words = nltk.FreqDist (freq)

nlp_words.plot(50)
# Out:
# [('educational', 6), ('of', 4), ('and', 4), ('the', 3), ('sr', 3), ('to', 3), ('university', 2), ('is', 2), ('institutions', 2), ('.', 2), ('telangana', 2), ('sri', 1), ('rajeshwara', 1), ('society', 1), (',', 1), ('parent', 1), ('body', 1), ('a', 1), ('45-year-old', 1), ('conglomerate', 1), ('with', 1), ('more', 1), ('than', 1), ('90,000', 1), ('students', 1), ('10,000', 1), ('teaching', 1), ('non-teaching', 1), ('staff', 1), ('members', 1), ('academy', 1), ('governs', 1), ('95', 1), ('across', 1), ('andhra', 1), ('pradesh.the', 1), ('goal', 1), ('create', 1), ('an', 1), ('innovative', 1), ('learning', 1), ('ecosystem', 1), ('whose', 1), ('graduates', 1), ('significantly', 1), ('contribute', 1), ('growth', 1), ('india', 1), ('we', 1), ('plan', 1), ('transform', 1), ('system', 1), ('through', 1), ('three', 1), ('key', 1), ('differentiators', 1)]
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
import nltk
from nltk import FreqDist
text ="Sri Rajeshwara Educational Society, the parent body of SR University is a 45-year-old conglomerate of educational institutions with more than 90,000 students and 10,000 teaching and non-teaching staff members. SR Educational Academy governs 95 Educational Institutions across Telangana and Andhra Pradesh.The goal of SR University is to create an innovative learning educational ecosystem whose graduates significantly contribute to the growth of Telangana and India. We plan to transform the educational system through three key differentiators"
word = nltk.word_tokenize(text.lower())
freq = FreqDist(word)
print(freq.most_common(1000))

import matplotlib.pyplot as plt

import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline

sns.set(rc={'figure.figsize': (11.7,8.27)})
sns.set_style('darkgrid')

# Create freq dist and plot
nlp_words = nltk.FreqDist (freq)

nlp_words.plot(40)
# Out:
# [('educational', 6), ('of', 4), ('and', 4), ('the', 3), ('sr', 3), ('to', 3), ('university', 2), ('is', 2), ('institutions', 2), ('.', 2), ('telangana', 2), ('sri', 1), ('rajeshwara', 1), ('society', 1), (',', 1), ('parent', 1), ('body', 1), ('a', 1), ('45-year-old', 1), ('conglomerate', 1), ('with', 1), ('more', 1), ('than', 1), ('90,000', 1), ('students', 1), ('10,000', 1), ('teaching', 1), ('non-teaching', 1), ('staff', 1), ('members', 1), ('academy', 1), ('governs', 1), ('95', 1), ('across', 1), ('andhra', 1), ('pradesh.the', 1), ('goal', 1), ('create', 1), ('an', 1), ('innovative', 1), ('learning', 1), ('ecosystem', 1), ('whose', 1), ('graduates', 1), ('significantly', 1), ('contribute', 1), ('growth', 1), ('india', 1), ('we', 1), ('plan', 1), ('transform', 1), ('system', 1), ('through', 1), ('three', 1), ('key', 1), ('differentiators', 1)]
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # SCHOOL OF  CSE &AI GRAPH

# %%
text ="Through a partnership with one of the world’s biggest tech companies, SR University’s cutting-edge programs have been designed with a blend of pragmatic and theoretical concepts that build a firm foundation for students in the core areas of Computer Science & Artificial IntelligVISIT THIS  FOR MORE INFORMATION \nhttps://sru.edu.in/schools/school-of-cse-ai"
word = nltk.word_tokenize(text.lower())
freq = FreqDist(word)
print(freq.most_common(100))

import matplotlib.pyplot as plt

import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline

sns.set(rc={'figure.figsize': (11.7,8.27)})
sns.set_style('darkgrid')

# Create freq dist and plot
nlp_words = nltk.FreqDist (freq)

nlp_words.plot(50)
# Out:
# [('a', 3), ('of', 3), ('with', 2), ('the', 2), ('’', 2), ('s', 2), ('for', 2), ('through', 1), ('partnership', 1), ('one', 1), ('world', 1), ('biggest', 1), ('tech', 1), ('companies', 1), (',', 1), ('sr', 1), ('university', 1), ('cutting-edge', 1), ('programs', 1), ('have', 1), ('been', 1), ('designed', 1), ('blend', 1), ('pragmatic', 1), ('and', 1), ('theoretical', 1), ('concepts', 1), ('that', 1), ('build', 1), ('firm', 1), ('foundation', 1), ('students', 1), ('in', 1), ('core', 1), ('areas', 1), ('computer', 1), ('science', 1), ('&', 1), ('artificial', 1), ('intelligvisit', 1), ('this', 1), ('more', 1), ('information', 1), ('https', 1), (':', 1), ('//sru.edu.in/schools/school-of-cse-ai', 1)]
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # school of engineering-word count graph

# %%
text ="  An engineering degree is a stepping stone for the best high-paying, fast-growing career. It opens doors to a diverse range of employment opportunities pushing technological frontiers, creating innovative solutions, and making the world a better place.VISIT THIS FOR MORE INFORMATION \nhttps://sru.edu.in/schools/school-of-engineering"
word = nltk.word_tokenize(text.lower())
freq = FreqDist(word)
print(freq.most_common(100))

import matplotlib.pyplot as plt

import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline

sns.set(rc={'figure.figsize': (11.7,8.27)})
sns.set_style('darkgrid')

# Create freq dist and plot
nlp_words = nltk.FreqDist (freq)

nlp_words.plot(20)
# Out:
# [('a', 3), (',', 3), ('for', 2), ('the', 2), ('an', 1), ('engineering', 1), ('degree', 1), ('is', 1), ('stepping', 1), ('stone', 1), ('best', 1), ('high-paying', 1), ('fast-growing', 1), ('career', 1), ('.', 1), ('it', 1), ('opens', 1), ('doors', 1), ('to', 1), ('diverse', 1), ('range', 1), ('of', 1), ('employment', 1), ('opportunities', 1), ('pushing', 1), ('technological', 1), ('frontiers', 1), ('creating', 1), ('innovative', 1), ('solutions', 1), ('and', 1), ('making', 1), ('world', 1), ('better', 1), ('place.visit', 1), ('this', 1), ('more', 1), ('information', 1), ('https', 1), (':', 1), ('//sru.edu.in/schools/school-of-engineering', 1)]
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # school of Business word count graph

# %%
text ="The School of Business equips students with a bedrock of management skills to navigate today's complex business environment. A dynamic curriculum designed in conjunction with academic and industry practitioners provides them with opportunities to master new skills and explore varied perspectives.VISIT THIS FOR MORE INFORMATION  \n https : // sru . edu . in schools business innovation entrepreneurship"
word = nltk.word_tokenize(text.lower())
freq = FreqDist(word)
print(freq.most_common(100))

import matplotlib.pyplot as plt

import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline

sns.set(rc={'figure.figsize': (11.7,8.27)})
sns.set_style('darkgrid')

# Create freq dist and plot
nlp_words = nltk.FreqDist (freq)

nlp_words.plot(100)
# Out:
# [('business', 3), ('with', 3), ('.', 3), ('of', 2), ('a', 2), ('skills', 2), ('to', 2), ('in', 2), ('and', 2), ('the', 1), ('school', 1), ('equips', 1), ('students', 1), ('bedrock', 1), ('management', 1), ('navigate', 1), ('today', 1), ("'s", 1), ('complex', 1), ('environment', 1), ('dynamic', 1), ('curriculum', 1), ('designed', 1), ('conjunction', 1), ('academic', 1), ('industry', 1), ('practitioners', 1), ('provides', 1), ('them', 1), ('opportunities', 1), ('master', 1), ('new', 1), ('explore', 1), ('varied', 1), ('perspectives.visit', 1), ('this', 1), ('for', 1), ('more', 1), ('information', 1), ('https', 1), (':', 1), ('//', 1), ('sru', 1), ('edu', 1), ('schools', 1), ('innovation', 1), ('entrepreneurship', 1)]
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # school of sciences wordcount graph

# %%
text =" The School of Sciences is multi-disciplinary in nature with faculty belonging to different disciplines: Mathematics, Physics, Chemistry, Psychology, Cognitive Science and Environmental Sciences. Programs offered here focus on building a groundwork for excellence among scholars and academVISIT THIS  FOR INFORMATION  \n https: // sru . edu . in  schools  school of sciences"
word = nltk.word_tokenize(text.lower())
freq = FreqDist(word)
print(freq.most_common(100))

import matplotlib.pyplot as plt

import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline

sns.set(rc={'figure.figsize': (11.7,8.27)})
sns.set_style('darkgrid')

# Create freq dist and plot
nlp_words = nltk.FreqDist (freq)

nlp_words.plot(100)
# Out:
# [(',', 4), ('sciences', 3), ('.', 3), ('school', 2), ('of', 2), ('in', 2), (':', 2), ('and', 2), ('for', 2), ('the', 1), ('is', 1), ('multi-disciplinary', 1), ('nature', 1), ('with', 1), ('faculty', 1), ('belonging', 1), ('to', 1), ('different', 1), ('disciplines', 1), ('mathematics', 1), ('physics', 1), ('chemistry', 1), ('psychology', 1), ('cognitive', 1), ('science', 1), ('environmental', 1), ('programs', 1), ('offered', 1), ('here', 1), ('focus', 1), ('on', 1), ('building', 1), ('a', 1), ('groundwork', 1), ('excellence', 1), ('among', 1), ('scholars', 1), ('academvisit', 1), ('this', 1), ('information', 1), ('https', 1), ('//', 1), ('sru', 1), ('edu', 1), ('schools', 1)]
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # School of agriculture

# %%
text ="Agriculture is the backbone of the Indian economy. Graduates of SRU’s Agriculture program will have technical knowledge in crop raising, effective use of fertilizers, integrated pest management, seed conditioning and smart technology. The graduates are also exposed to livestock management. The course balances theoretical aspects with practical issues such as agroeconomics, smart food processing technologies, and crop management.             VISIT THIS FOR MORE INFORMATION \n https: sru.edu.in schools school of agriculture"
word = nltk.word_tokenize(text.lower())
freq = FreqDist(word)
print(freq.most_common(100))

import matplotlib.pyplot as plt

import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline

sns.set(rc={'figure.figsize': (11.7,8.27)})
sns.set_style('darkgrid')

# Create freq dist and plot
nlp_words = nltk.FreqDist (freq)

nlp_words.plot(100)
# Out:
# [(',', 5), ('the', 4), ('of', 4), ('.', 4), ('agriculture', 3), ('management', 3), ('graduates', 2), ('crop', 2), ('and', 2), ('smart', 2), ('is', 1), ('backbone', 1), ('indian', 1), ('economy', 1), ('sru', 1), ('’', 1), ('s', 1), ('program', 1), ('will', 1), ('have', 1), ('technical', 1), ('knowledge', 1), ('in', 1), ('raising', 1), ('effective', 1), ('use', 1), ('fertilizers', 1), ('integrated', 1), ('pest', 1), ('seed', 1), ('conditioning', 1), ('technology', 1), ('are', 1), ('also', 1), ('exposed', 1), ('to', 1), ('livestock', 1), ('course', 1), ('balances', 1), ('theoretical', 1), ('aspects', 1), ('with', 1), ('practical', 1), ('issues', 1), ('such', 1), ('as', 1), ('agroeconomics', 1), ('food', 1), ('processing', 1), ('technologies', 1), ('visit', 1), ('this', 1), ('for', 1), ('more', 1), ('information', 1), ('https', 1), (':', 1), ('sru.edu.in', 1), ('schools', 1), ('school', 1)]
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # SRIX

# %%
text ="  SRiX is the Technology Business Incubator - TBI of SR University, Telangana.We nurture startup ideas and technology innovations from their idea stage, provide the resources required to build products and find customer acceptance. We also support the startups to gear for growth through access to global partners and investors.SRiX brings entrepreneurs, mentors, researchers, and academicians together to create an inspiring ecosystem to transform ideas into actions. The deep interaction between the theory and practice of entrepreneurship brings the best out of both, creating unique synergies.SRiX intends to be an active catalyst for the growth of Telanganas startup eco-system. We are an open incubator that welcomes entrepreneurs from all over the country.Be a part of our network to participate in stimulating conversations, innovative thinking, and forward-looking startups. Together, let us ignite the spark of new ideas and ventures."
word = nltk.word_tokenize(text.lower())
freq = FreqDist(word)
print(freq.most_common(100))

import matplotlib.pyplot as plt

import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline

sns.set(rc={'figure.figsize': (11.7,8.27)})
sns.set_style('darkgrid')

# Create freq dist and plot
nlp_words = nltk.FreqDist (freq)

nlp_words.plot(50)
# Out:
# [('the', 9), (',', 9), ('and', 7), ('to', 7), ('of', 6), ('.', 5), ('ideas', 3), ('an', 3), ('technology', 2), ('incubator', 2), ('startup', 2), ('from', 2), ('we', 2), ('startups', 2), ('for', 2), ('growth', 2), ('brings', 2), ('entrepreneurs', 2), ('together', 2), ('srix', 1), ('is', 1), ('business', 1), ('-', 1), ('tbi', 1), ('sr', 1), ('university', 1), ('telangana.we', 1), ('nurture', 1), ('innovations', 1), ('their', 1), ('idea', 1), ('stage', 1), ('provide', 1), ('resources', 1), ('required', 1), ('build', 1), ('products', 1), ('find', 1), ('customer', 1), ('acceptance', 1), ('also', 1), ('support', 1), ('gear', 1), ('through', 1), ('access', 1), ('global', 1), ('partners', 1), ('investors.srix', 1), ('mentors', 1), ('researchers', 1), ('academicians', 1), ('create', 1), ('inspiring', 1), ('ecosystem', 1), ('transform', 1), ('into', 1), ('actions', 1), ('deep', 1), ('interaction', 1), ('between', 1), ('theory', 1), ('practice', 1), ('entrepreneurship', 1), ('best', 1), ('out',
# ...

# %% [markdown]
# # wordcount graph for dataset

# %%
file=open("D:\documents\SRU CHATBOT.txt.","r+")
wordcount={}
for word in file.read().split():
    if word not in wordcount:
        wordcount[word] = 1
    else:
        wordcount[word] += 1
print (word,wordcount)
file.close();
import matplotlib.pyplot as plt

import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline

sns.set(rc={'figure.figsize': (11.7,8.27)})
sns.set_style('darkgrid')

# Create freq dist and plot
nlp_words = nltk.FreqDist (wordcount)

nlp_words.plot(50)
# Out:
# soon {'hi|hey|hello,': 1, 'Hello,': 1, 'WELCOME': 1, 'TO': 8, 'SRU': 9, 'BOT': 1, '!': 1, 'THIS': 39, 'ARE': 1, 'THE': 7, 'SERVICES': 3, 'WE': 2, 'PROVIDE': 1, '1.': 3, 'ABOUT': 8, '2.': 3, 'ACADEMICS': 2, '3.': 2, 'ADMISSIONS': 2, '4.': 2, 'RESEARCH': 6, '5.': 2, 'CAREERS': 2, '6.': 2, 'PLACEMENTS': 2, '7.': 2, 'CAMPUS': 2, 'LIFE': 2, '8.': 2, 'SRIX': 2, '9.': 2, 'CONTACT': 2, 'OR': 2, 'VISIT': 41, 'US': 2, '10.': 2, 'SRAAP': 2, '[': 1, 'ATTENDANCE': 1, 'PORTEL': 1, ']': 1, '11.SOCIAL': 1, 'MEDIA': 1, '12.NEWS': 2, '13.NIRF': 2, '14.UGC': 2, '15.EAMCET': 2, 'CODE': 2, '16.LOCATION': 2, '17.': 1, 'VISION': 2, '18.': 1, 'LEADERSHIP(only': 1, 'few)': 3, '19.': 1, 'BOARD': 2, 'OF': 19, 'ADVISORS(only': 1, '20.': 1, 'AWARDS': 2, 'AND': 21, 'RECOGNIZATION(only': 1, '21': 2, 'HOLIDAYS': 3, 'LIST': 3, '22': 2, 'EXAM': 2, 'BRANCH': 2, '23': 2, 'ALUMINI': 2, '24.WEBLOGIN': 2, '25.COURSES': 2, '26.PHD': 2, 'PROGRAMS': 5, '27.quit': 1, '(TO': 1, 'EXIT)': 1, 'IS': 3, 'UNIVERSITY': 1, 'OFFICAL': 
# ...
